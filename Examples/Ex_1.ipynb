# %% [markdown]
# <a href="https://colab.research.google.com/github/JoyeBright/domain-adapt-mt/blob/main/Examples/Ex_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook, we show how to use **[DomainAdapt-MT v1.0.0](https://github.com/JoyeBright/domain-adapt-mt)** to do data selection for training MT models. 😀

# %% [markdown]
# ## 🌍 Out-of-Domain Data
#
# We download a large out-of-domain English–French corpus (**CCAligned v1**) from the [OPUS repository](https://opus.nlpl.eu/CCAligned.php).

# %%
# !wget  https://object.pouta.csc.fi/OPUS-CCAligned/v1/moses/en-fr.txt.zip
# Out:
# --2025-06-13 11:39:46--  https://object.pouta.csc.fi/OPUS-CCAligned/v1/moses/en-fr.txt.zip
# Resolving object.pouta.csc.fi (object.pouta.csc.fi)... 86.50.254.18, 86.50.254.19
# Connecting to object.pouta.csc.fi (object.pouta.csc.fi)|86.50.254.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1013655142 (967M) [application/zip]
# Saving to: ‘en-fr.txt.zip’
#
# en-fr.txt.zip       100%[===================>] 966.70M  20.9MB/s    in 49s
#
# 2025-06-13 11:40:36 (19.8 MB/s) - ‘en-fr.txt.zip’ saved [1013655142/1013655142]

# %%
# !unzip /content/en-fr.txt.zip
# Out:
# Archive:  /content/en-fr.txt.zip
# replace README? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: README
#   inflating: LICENSE
#   inflating: CCAligned.en-fr.en
#   inflating: CCAligned.en-fr.fr
#   inflating: CCAligned.en-fr.xml

# %% [markdown]
# ## ⚠️ Downsizing the Out-of-Domain Corpus (for Demo Only)
#
# To show how the tool works in environments like Google Colab (which have limited memory), we downsize the OOD corpus.
# We randomly sample 1 million sentence pairs from the full CCAligned dataset:

# %%
# !paste /content/CCAligned.en-fr.en /content/CCAligned.en-fr.fr \
  | shuf \
  | head -n 1000000 \
  | tee >(cut -f1 > /content/sample.en) >(cut -f2 > /content/sample.fr)

# %% [markdown]
# ## 📘 In-Domain Data
#
# We use the [Unsupervised Domain Clusters](https://github.com/roeeaharoni/unsupervised-domain-clusters) dataset for in-domain data.
# For this example, we use only the **IT** domain subset, which we've uploaded to our drive. You can do the same.

# %%
# !unzip /content/multi_domain_new_split.zip -d /content/
# Out:
# Archive:  /content/multi_domain_new_split.zip
#    creating: /content/it/
#    creating: /content/koran/
#    creating: /content/law/
#    creating: /content/medical/
#    creating: /content/subtitles/
#   inflating: /content/it/dev.de
#   inflating: /content/it/dev.en
#   inflating: /content/it/test.de
#   inflating: /content/it/test.en
#   inflating: /content/it/train.de
#   inflating: /content/it/train.en
#   inflating: /content/koran/dev.de
#   inflating: /content/koran/dev.en
#   inflating: /content/koran/test.de
#   inflating: /content/koran/test.en
#   inflating: /content/koran/train.de
#   inflating: /content/koran/train.en
#   inflating: /content/law/dev.de
#   inflating: /content/law/dev.en
#   inflating: /content/law/test.de
#   inflating: /content/law/test.en
#   inflating: /content/law/train.de
#   inflating: /content/law/train.en
#   inflating: /content/medical/dev.de
#   inflating: /content/medical/dev.en
#   inflating: /content/medical/test.de
#   inflating: /content/medical/test.en
#   inflating: /content/medical/train.de
#   inflating: /content/medical/train.en
#   inflating: /content/subtitles/dev.de
#   inflating: /content/subtitles/dev.en
#   inflating: /content/subtitles/test.de
#   inflating: /content/subtitles/test.en
#   inflating: /content/subtitles/train.de
#   inflating: /content/subtitles/train.en
#   inflating: /content/subtitles/train.full.de
#   inflating: /content/subtitles/train.full.en

# %% [markdown]
# ## 🚀 Run the Data Selection Script
#
# Now that we have the required input files, we can use the data selection script from the repository:
# 👉 [domain-adapt-mt](https://github.com/JoyeBright/domain-adapt-mt)
#
# ### 📥 Step 1: Download the Script
#
# Download the main script directly:
# [main.py](https://github.com/JoyeBright/domain-adapt-mt/blob/main/main.py)
# Or
# You can also clone the full repo if preferred:
# ```bash
# git clone https://github.com/JoyeBright/domain-adapt-mt.git
# cd domain-adapt-mt

# %%
# !git clone https://github.com/JoyeBright/domain-adapt-mt.git
# Out:
# Cloning into 'domain-adapt-mt'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 23 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 320.83 KiB | 1.24 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
cd domain-adapt-mt
# Out:
# /content/domain-adapt-mt

# %%
# !python /content/domain-adapt-mt/main.py -ood_src /content/sample.en \
                                                               -ood_tgt /content/sample.fr \
                                                               -id /content/it/train.en
# Out:
# Streaming output truncated to the last 5000 lines.
# 115898
# Layout Count: %1
# Result Pages: 1 Languages
# Page : 1 Langues
# 115899
# 16-bit color depth
# Format: 16mm.
# 2 X 30 secondes
# 115900
# Definite
# indeed,
# Afin
# 115901
# Could not open output redirection for writing
# Do not fill out please *
# Une demande ne pas remplir*
# 115902
# This is not a KDE Vocabulary document.
# I am not a robot.
# Je ne suis pas un robot.
# 115903
# If this option is disabled, changing the indentation level aligns a line to a multiple of the width specified in Indentation width.
# ← Previous postBlack and white conversion Next post →Change Colors or Swap Out Material
# ← Article précédentConversion en noir et blanc Article suivant →Changer les couleurs ou changer de matériau
# 115904
# Unselect all items in the current view
# (You can unsubscribe at any time.)
# (vous pouvez vous désinscrire à tout moment)
# 115905
# Ask for every conflict
# Everything starts with a problem to resolve, a need, a conflict (FR).
# Tout part d’un problème à résoudre, d’un besoin, d’un conflit.
# 115906
# Lock page
# Lock and Lock Accessories
# Serrures et accesoires
# 115907
# Check for High Score
# View top scores
# Voir le top score
# 115908
# C3
# Third:
# Troisième :
# 115909
# Available Remotes
# Remote support you can count on.
# Une assistance à distance sur laquelle vous pouvez compter.
# 115910
# Jumps to the next input field in the document.
# Start a Data project now
# Commencer un projet Data maintenant
# 115911
# Timeout in seconds
# Time per photo in seconds
# Temps par photo en seconde
# 115912
# v1
# Reference: V1
# Référence : V1
# 115913
# Gimmix
# File extension: .cm
# Extension de fichier: .cm
# 115914
# Post-increment
# And the increment.
# Et l'augmentation.
# 115915
# decawatt; decawatts; daW
# — Accumulations of demerit —
# — Amoncellements de démérite —
# 115916
# /text/shared/guide/hyperlink_rel_abs.xhp
# Download my file with this link : https://download.gg/en/file-6166451_3bcb66a38e15c312
# Téléchargez mon fichier à cette adresse : https://download.gg/fr/file-6166451_3bcb66a38e15c312
# 115917
# Most standard fraction notations will be converted when available
# All the stages with a lot of details like % on one screen.
# Toute les spéciales avec les beaucoup de détails (les %) sur un seul écran.
# 115918
# Polka
# Poles
# Pôles
# 115919
# translator-credits
# TRANSLATION MEMORIES.
# MÉMOIRES DE TRADUCTION.
# 115920
# useractions. xml
# XML Tutorial - Contents
# Tutoriel XML - Contenu
# 115921
# The Editor Window
# Editor &
# Rédaction &
# 115922
# You must now provide a password for the certificate request. Please choose a very secure password as this will be used to encrypt your private key.
# All mobile phones can be locked by a password. It's a basic way of protecting your personal information if your phone is ever lost or stolen.
# Tous les cellulaires peuvent être verrouillés au moyen d'un mot de passe. Il s'agit là d'une façon élémentaire de protéger votre information personnelle si jamais vous perdez votre téléphone ou que vous vous le faites voler.
# 115923
# kdetoys
# Mortis:
# mort:
# 115924
# Use a background pixmap
# Background image by pixabay.com
# L'image de fond fournit par pixabay.com
# 115925
# Day of Month to start Forecast:
# Date: day - month - year
# Date : jour — mois — année
# 115926
# Chemical Solver Help
# Physico-chemical solutions
# Solutions physico-chimiques
# 115927
# Click the colour that you want to use.
# Click on the image of your choice.
# Cliquez sur l'image de votre choix.
# 115928
# CreateUnoDialog Function [Run-time]
# Execute MiNETConfig.exe
# Exécutez MiNETConfig.exe
# 115929
# the float 0.0 (zero)
# The 0 crossed out is a Zero
# Le 0 barré est un Zero
# 115930
# AC adaptor plugged in
# Power connector: Adapter (included)
# Connecteur électrique : adaptateur (inclus)
# 115931
# Print " The current hour is " & Hour( Now )
# Date and Hour UTC:
# Date et heure UTC:
# 115932
# Copy the selected text or item(s) to the clipboard
# Copy (or copy to the Clipboard)
# Copiez (ou copiez dans le presse-papiers)
# 115933
# Save as image â¦
# Save as image
# Enregistrer comme image
# 115934
# To reiterate, inside a double-quoted string, it' s valid to not surround array indexes with quotes so "$foo[bar] "is valid.
# Common mis-spelled searches are myb ip, my i.p, my i p, muyip, my i[p, m yip and my ip] thats why myb ip, my i.p, my i p, muyip, my i[p, m yip, and my ip] are in our opion are the same as my ip
# Les recherches courantes mal orthographiées sont myb ip, mon IP, mon IP, muyip, mon IP, mon IP et mon IP] c'est pourquoi myb ip, mon IP, mon IP, muyip, mon IP, mon IP, et mon IP] sont dans notre opinion sont les mêmes que mon IP
# 115935
# Enables FTP's "passive" mode. This is required to allow FTP to work from behind firewalls.
# CO2.Earth This email address is being protected from spambots. You need JavaScript enabled to view it.
# CO2.Terre Cette adresse e-mail est protégée du spam. Vous devez activer Javascript pour la voir.
# 115936
# Keep in mind this simple rule: defence in depth.
# Mental strategy: Respect the basics →
# Stratégie mentale : Respecter les bases →
# 115937
# A crossword puzzle game and editor for KDE 4
# OK. But a tutorial rooms can auto .. ??
# Il est correct. Mais une salle de tutorat peut auto .. ??
# 115938
# The link to the server will be closed as soon as the execution of the script ends, unless it' s closed earlier by explicitly calling mysql_close().
# All guided tours are cancelled until further notice.
# Tous les tours guidés sont annulés jusqu’à nouvel ordre.
# 115939
# Parse QMake project files
# Qstit - Surtitling software
# Qstit - Logiciel de surtitrage
# 115940
# Number of sectors:
# In various sectors :
# Dans différents secteurs :
# 115941
# Edit with Qt Designer...
# EDITOR AND DEVELOPMENT OF THE SITE:
# EDITEUR ET DEVELOPPEMENT DU SITE :
# 115942
# Importing'UNIX 'mail folders ('. mbx ')...
# Importing databases: Text files, MS Access (MDB file), SQLite and Kexi
# Importation de bases de données: fichiers texte, MS Access (fichier MDB), SQLite et Kexi
# 115943
# Cannot edit root tag
# JUser: :_load: Unable to load user with ID: 151573
# JUser::_load : impossible de charger l'utilisateur ayant l'ID 151573
# 115944
# Please enter a path.
# Find a route from
# Trouver un itinéraire à partir
# 115945
# Inserting widgets - text fields
# This is widget text.
# Il s'agit de texte.
# 115946
# New Root
# NEW FABRICATION
# nouveau fabrication
# 115947
# Write image file to:
# Send a file
# Envoyer un Fichier
# 115948
# Setting Gamma Correction
# Replaces the CH109b reference.
# Remplace la référence CH109b.
# 115949
# putzer@kde. org
# File extension: .kar
# Extension de fichier: .kar
# 115950
# Show names of comets within
# Subscribe to Updates - Status Page - CometChat
# M'abonner aux mises à jour - État des services - CometChat
# 115951
# Change priority
# Subject to change!
# Sujet à changement!
# 115952
# New Alarms & & Templates
# New lines of production in order to realise any type of audio visual communication.
# Nouvelles lignes de production pour la realisation de n’importe quel processus de communication audiovisuelle.
# 115953
# File %1 already exists. Are you sure you want to overwrite it?
# Attach a resume to a Word or PDF file, maximum size 1MB
# Joindre un CV à un fichier Word ou PDF, taille maximale 1MB
# 115954
# If both boxes are marked and you edit the disabled Basic Code in the $[officename] Basic IDE, the original Microsoft Basic code will be saved when saving in the Microsoft format.
# Please help us to improve. We kindly ask you to fill out the following field entering the characters you find after the code in the bottom/right of the order form for your missing stickers (the field is not required).
# Aidez-nous à améliorer notre service! Nous vous prions de remplir le champ ci-dessous et introduire les caractères indiquées après la partie fixe du code imprimé en bas à droite du bon de commande de cartes/stickers manquants qui se trouve au milieu de votre album (le champ n’est pas obligatoire).
# 115955
# If a value is not entered, the default is factor 2.
# Risk Level: 0.2
# Niveau de risque: 0.2
# 115956
# INFO function
# Infotainment
# Motionnet
# 115957
# Photo Importer
# By Importator
# Par Importateur
# 115958
# Folder & contains:
# Handle form: U type can be folded
# Forme de poignée: Le type U peut être plié
# 115959
# Configure where images and metadata are stored
# In particular the data subject can object in full or part:
# En particulier les personnes concernées ont le droit de s'opposer, totalement ou partiellement:
# 115960
# & knotes; is a program that lets you write the computer equivalent of sticky notes. The notes are saved automatically when you exit the program, and they display when you open the program.
# Try emptying and clearing the cache and cookies of your browser and restarting it&
# Essayez de vider et effacer le cache et les cookies de votre navigateur, puis le redémarrer.
# 115961
# San Francisco Gotera
# San Francisco, United States
# New York, États-Unis
# 115962
# Y-position (AU)
# Find the Reference Angle
# Trouver l'angle de référence
# 115963
# Confirm Manual Enter
# Enter confirmation code:
# Entrez le code de validation:
# 115964
# Girl
# woman
# naine
# 115965
# See also Appendix I, fclose(), fgets(), fsockopen(), file(), file_exists(), is_readable(), socket_set_timeout(), and popen().
# GENFUNC Performs many general numeric and alphanumeric operations including =, contains, starts with, >, <, >=, <=, +, -, /, *, %, assign, round and many more operators.
# GENFUNC Ce plug-in effectue de nombreuses opérations numériques et alphanumériques générales, dont =, contient, commence par, >, <, >=, <=, +, -, /, *, %, assigner, arrondir et de nombreux autres opérateurs.
# 115966
# If you need to set a timeout for reading / writing data over the socket, use socket_set_timeout(), as the timeout parameter to fsockopen() only applies while connecting the socket.
# The IP address 109.230.227.238 offers the following web services. This means that the following ports are open or closed. This will help you quickly determine which services are available on the server. The system ports are standardized and offer fixed services. The system ports are defined from 0 to 1023, we show a small selection of the most important ports.
# L'adresse IP 109.230.227.238 offre les services Web suivants. Cela signifie que les ports suivants sont ouverts ou fermés. Cela vous aidera à déterminer rapidement quels services sont disponibles sur le serveur. Les ports du système sont standardisés et offrent des services fixes. Les ports du système sont définis de 0 à 1023, nous présentons une petite sélection des ports les plus importants.
# 115967
# The tangent, inverse tangent, cotangent and inverse cotangent respectively.
# Take the inverse tangent of .
# Prendre la la réciproque de la tangente de .
# 115968
# Pcm2
# About S2G
# A propos de S2G
# 115969
# Open the $[officename] Calc spreadsheet containing the cell range that you want to insert.
# The first step would be to authorize emails from @kgouin@lglimmobilier.com,glarose@lglimmobilier.com,alanglade@lglimmobilier.com.
# Un bon moyen serait d'autoriser les courriels provenant de kgouin@lglimmobilier.com,glarose@lglimmobilier.com,alanglade@lglimmobilier.com.
# 115970
# Maximize Current Dock
# Modern technique
# Technique moderne
# 115971
# is a superset of
# {{if !full}}
# {{:ville}}
# 115972
# MPlayer
# DYNAMIC 3D/VR SEATS
# SIÈGES DYNAMIQUES 3D/VR
# 115973
# tab page of the
# In the General tab :
# Dans l'onglet Général :
# 115974
# MPEG1
# Filename: l1.jpg
# Nom du fichier: l1.jpg
# 115975
# /text/smath/01/03090905.xhp
# HD9:04xHamster
# HD1:38xHamster
# 115976
# Sets the multiplayer mode to single player normal. See.
# multiplayer mode; simple operation;
# le mode multijoueur; opération simple;
# 115977
# By disabling this, & kopete; 's groups are hidden, and contacts are divided only into Online Contacts and Offline Contacts.
# Avoid waiting lines. Contribute online.
# Évitez les files d’attente et cotisez en ligne dès maintenant.
# 115978
# Focus input field
# Focusing System
# Système de focalisation
# 115979
# This file already exists. Do you want to overwrite it?
# • NEW MYCLUB - Every element has been redone, from how you sign players, to special versions of players released throughout the year
# • NOUVEAU MYCLUB - Tous les éléments ont été revus, de la signature des joueurs aux versions spéciales de joueurs proposées tout au long de l'année.
# 115980
# %1: %2 %3
# (2 Thess. 3, 1)
# (2 Thessaloniciens 3.1)
# 115981
# Add Alias
# Coupon added
# Coupon ajouté
# 115982
# If you use & konqueror; tabs, you can drag and drop between tabs by dragging the file to the tab label, without letting go yet. The destination tab will pop to the front, allowing you to continue dragging and then drop the file.
# Remember to book to prolong the moment with our menus “kills pig” La Tupina and Kuzina.
# Pensez à réserver pour prolonger le moment avec nos menus “tue cochon” à La Tupina et à Kuzina.
# 115983
# Here you can enter the files you want to compare.
# This form allows to search the papers published between and
# Ce formulaire vous permet de rechercher les travaux publiés entre et
# 115984
# as a text string.
# Links : text
# Liens : texte
# 115985
# 1st, 2nd, 3rd Group
# 2nd and 3rd levels
# 2ème et 3ème niveaux
# 115986
# Unable to enable autocommit
# I can't login!
# Je ne peux pas me connecter !
# 115987
# If " By author " is chosen from the list, the colour is automatically determined by $[officename] and modified according to the corresponding author of the changes.
# You can use the above address to request a change of address on our mailing list. Please include your old address label with the postal code if possible.
# Vous pouvez utiliser l'adresse ci-dessus pour demander qu'on effectue un changement d'adresse à notre liste de distribution. Veuillez inclure l'étiquette avec votre ancienne adresse, y compris le code postal, si possible.
# 115988
# Press this button to modify the currently selected scheme.
# Please press Back and modify the information provided accordingly.
# Appuyez sur Retour et de modifier les données saisies.
# 115989
# Reset layout command to default
# General: info{__@_REMOVE_THIS_PART_@__}
# Général: info{__@_REMOVE_THIS_PART_@__}
# 115990
# Returns the first n chars of the string.
# Returns the number of the word s1 in the string s2.
# Retourne le numéro du mot s1 dans la chaine s2.
# 115991
# Right-click a column in the preview to set the format or to hide the column.
# Please select a Moen product before searching for purchase locations
# Veuillez sélectionner un produit Moen avant de chercher des lieux d'achat
# 115992
# Invalid interface index
# Registration is disabled.
# L’inscription est désactivée.
# 115993
# /text/swriter/guide/using_thesaurus.xhp
# Language selection _ Davidts Ligthing
# Sélection de la langue _ Davidts Ligthing
# 115994
# Torrent
# By TorrentRockYou
# Par TorrentRockYou
# 115995
# Error writing to PTY
# Describe the incorrect data that MAST has about you
# Décrivez les données incorrectes que MAST a à votre sujet
# 115996
# See the documentation for these functions for an example.
# Sources of example application are here
# Les sources de l’application exemple sont ici
# 115997
# Configure options
# Following are the various configuring options:
# Les diverses options de paramétrage sont les suivantes :
# 115998
# Replace the second placeholder with the text.
# write down this second value.
# notez la seconde valeur.
# 115999
# In the examples following, the process is always ksnapshot-23151.
# Setpoint commands automatically sent every 2 seconds
# Commandes de consigne envoyées automatiquement toutes les 2 secondes
# 116000
# Download (KB/ s):
# Download PDF (1.6MB) in:
# Télécharger PDF (1.6MB) dans:
# 116001
# Automatic Display of FITS upon capture: When checked, KStars will display captured FITS in KStars FITS Viewer tool. If you use the Capture Image Sequence tool, all captured images will be saved to disk regardless of this option.
# All settings can be exported and then imported subsequently into the same site or a different location and serves as a good backup.
# Tous les paramètres peuvent être exportés puis importés par la suite dans le même site ou à un autre emplacement et constituent une bonne sauvegarde.
# 116002
# /text/swriter/02/10070000.xhp
# 100778 Translated words -
# 100778 Mots traduits -
# 116003
# %1 cubic terameters
# Volume : 1 liter
# Contenance : 1 litre
# 116004
# Could not read post.
# There are no search terms for this letter.
# NOn n’a pas trouvé de mot-clé correspondant à cette lettre.
# 116005
# & Save changes periodically
# Changes or updates
# Changements ou mises à jour
# 116006
# Instead of executing the user command directly with su, & kdesu; executes a little stub program called kdesu_stub. This stub (running as the target user), requests some information from & kdesu; over the pty/ tty channel (the stub's stdin and stdout) and then executes the user's program. The information passed over is: the X display, an X authentication cookie (if available), the PATH and the command to run. The reason why a stub program is used is that the X cookie is private information and therefore cannot be passed on the command line.
# About us _ installation instructions _ error _ care _ Story _ function _ Motorsport _ repair _ exchange _ New _ Privacy Policy
# à propos de nous _ Les instructions d'installation de _ erreur _ soins _ Histoire _ fonction _ Motorsport _ réparation _ échange _ Nouveau _ Politique de confidentialité
# 116007
# Section
# In this section
# Dans cette section Introduction
# 116008
# Filename Layout Chooser
# Select a file…
# Sélectionner un fichier…
# 116009
# Select such a call information line to activate the call destination.
# Activate using the received code
# Activer en utilisant le code reçu
# 116010
# After comparing the directories & kdiff3; also evaluates a proposal for a merge operation. This is shown in the "Operation" column. You can modify the operation by clicking on the operation you want to change. A small menu will popup and allows you to select an operation for that item. (You can also select the most needed operations via keyboard. Ctrl+1/ 2/ 3/ 4/ Del will select A/ B/ C/ Merge/ Delete respectively if available.) This operation will be executed during the merge. It depends on the item and on the merge-mode you are in, what operations are available. The merge-mode is one of
# Multiple Category Selections Would you like to search within several categories? If so, simply use the CTRL-Button and choose the different categories in the dropdown menu with one click.
# Rechercher dans plusieurs catégories Voulez-vous rechercher dans plusieurs catégories? Utilisez la touche contrôle au clavier et choissisez les catégories dans le menu déroulant avec un simple clic.
# 116011
# converting; to contours
# Converting sections
# Conversion des sections
# 116012
# editing;data binding of XForms
# The mapping of each table pulled from XPressEntry is shown below.
# Le mappage de chaque table extraite de XPressEntry est présenté ci-dessous.
# 116013
# sText = InputBox( " Please enter a phrase: " , " Dear User " )
# Please fill in a valid email address.
# Veuillez insérer une adresse e-mail valide.
# 116014
# Configure LDAP Servers
# Download and install Contenta Converter
# Télécharger et installer Contenta Converter
# 116015
# New Configuration Not Saved
# New condition. Never used
# Neuf / Jamais porté
# 116016
# Must supply a valid parent.
# …Qualified Babysitter upon request
# …Babysitter agréé sur demande
# 116017
# A cursor indicating diagonal movement down and to the left.
# Turn left at the traffic lights, proceed to the second traffic lights and then turn left.
# Tourner à gauche aux feux de circulation, poursuivre jusqu’aux seconds feux de circulation et tourner à gauche.
# 116018
# Capital Gain (short term)
# PayBright financing
# Financement PayBright
# 116019
# Use relative path for & saving
# "Saving Option"
# "Option économique"
# 116020
# Changes in configuration files and folders
# - internal changes in accepting data types.
# - changements internes dans l'acceptation des types de données.
# 116021
# The package doesn't provide a valid Installed-Size control field. See Debian Policy 5.6.20.
# If Notification.dll is missing in one or both directories, program or game that uses this file cannot find it and cannot receive required data, so you get error like that:
# Si Notification.dll manque dans un ou les deux répertoires, le programme ou jeu qui utilise ce fichier ne le trouveront pas et ne pourront pas recevoir les données requises, donc vous obtiendrez des erreurs comme ça :
# 116022
# The DTEP name from where this DTEP inherits the tags.
# Tag Archives: lit
# Archives par étiquette : lit
# 116023
# AisleRiot provides a rule-based solitaire card engine that allows many different games to be played.
# Combine multiple games on the same dashboard.
# La possibilité de combiner plusieurs jeux sur le même dashboard.
# 116024
# Piedmont
# Country.
# Pays.
# 116025
# Keep daemon
# How to keep things
# Comment garder les choses
# 116026
# Toggle display of Messier object symbols
# Exceed expectations using content intelligence.
# Dépassez les attentes grâce à l'intelligence de contenu
# 116027
# Specifies the degree and type of solarisation.
# AND SOLARIUM
# ET SOLARIUM
# 116028
# Manager's Name
# Manager
# Directrice
# 116029
# A valid entry would have the form @@#1234567@@.
# Valid characters: 123456789
# Personnages valides: 123456789
# 116030
# Cannot create transactions when no account is selected.
# Dynacare Plus - Can't access your account
# Dynacare Plus - Vous ne pouvez pas accéder à votre compte
# 116031
# MaxClients:
# About MaxWin
# Au sujet de MaxWin
# 116032
# Davenport
# … and Scott:
# … et Scott :
# 116033
# Small font sizes for titles
# For small volumes, 1
# Pour les petits volumes, 1
# 116034
# Hyperbolic Sine
# hyperbolic sine
# sinus hyperbolique
# 116035
# Sub ExampleRmDir
# SUBSCRIBE:
# 2. Abonnez-vous:
# 116036
# Try to free up one or more Hole piles early.
# A tested model that can quickly be scaled up in a new sector or geographic area; or
# Un modèle éprouvé qui peut rapidement être déployé à grande échelle dans d’autres secteurs ou zones géographiques ; ou
# 116037
# IsMissing function [Run-time]
# → Events calendar → TRASLATIO SEDIS
# → Calendrier des événements → TRASLATIO SEDIS
# 116038
# DNG Converter...
# by Clym
# par Clym
# 116039
# You need korundum4 from & kde; 4 kdebindings module or from your distribution to run this template.
# 4. Q: Can I get everything customized here?
# 4. Q: Puis-je tout personnaliser ici?
# 116040
# This button swaps the search string with the replace string, so you can revert a search/ replace operation.
# Change your search criteria or click here to reset the list
# Changez vos critères de recherche ou cliquez-ici pour réinitialiser la liste
# 116041
# Click Tables to view the tables, or click Queries to view the queries.
# the statistics on the consultation of the different pages of the Website;
# les statistiques sur la consultation des différentes pages du Site;
# 116042
# ARCH B
# Reference: V2716a
# Référence: V2716a
# 116043
# Unable to establish SSH connection.
# No results for Telecom networks - FTTH
# Pas de résultats pour Réseaux télécoms - FTTH
# 116044
# OpenOffice.org 3 or StarOffice 9
# Posted on 01/05/2017 Inspiration 830
# Publié le 05/01/2017 Inspiration 829
# 116045
# Connect To & Other Network..
# Network& Links
# Réseauxet Liens
# 116046
# Todd Shoemaker
# shoegaze
# Dionysos
# 116047
# Name Selection
# Configuration selection
# Sélection de configuration
# 116048
# Checking this option will result in filenames being underlined, so that they look like links on a web page. Note: to complete the analogy, make sure that single click activation is enabled in the mouse control module.
# Below a list of all imet products; click on Features to filter products in order to easily find the machine you are interested in.
# Ci-dessous vous trouvez tous les produits imet, cliquez sur les caractéristiques pour filtrer les produits et trouver la machine qui vous intéresse.
# 116049
# slides;headers and footers
# USING LAPTOPS
# ORDINATEURS PORTABLES
# 116050
# Center the display on the selected object, and begin Tracking it.
# Visit us to best target your search
# Nous rendre visite afin de cibler le mieux possible votre recherche
# 116051
# Document templates
# Templates for
# Modèles pour
# 116052
# See also imagecolorat() and imagecolorexact().
# Available in following colors:
# disponible dans les couleurs suivantes:
# 116053
# Gorizia
# Givachoice
# Bienvenue à Givachoice.
# 116054
# Sorry, you cannot save your game play while you are editing. Please try menu item "%1".
# As in starting days, most of your traffic will come from Search engines only so why we should not optimise our site for better reachability?
# Comme dans les jours de début, la plupart de votre trafic viendra des moteurs de recherche seulement, pourquoi ne pas optimiser notre site pour une meilleure accessibilité?
# 116055
# Beylagan
# Bomonty Area
# La Région de Bomonti
# 116056
# lpadmin -p HeidelbergDigimaster9110 -v lpd: / 10.160.16.99/ mqueue -u deny: tackat, boss, waba -E -P / home/ kurt/ PPDs/ DVHV. ppd
# [{"id":17987289645139,"title":"Default Title","option1":"Default Title","option2":null,"option3":null,"sku":"","requires_shipping":false,"taxable":false,"featured_image":null,"available":true,"name":"Simple Beanie Hat Knitting Pattern","public_title":null,"options":["Default Title"],"price":450,"weight":0,"compare_at_price":450,"inventory_quantity":100,"inventory_management":"shopify","inventory_policy":"continue","barcode":""}]
# [{"id": 17987289645139, "title": "Titre par défaut", "option1": "Titre par défaut", "option2": null, "option3": null, "sku": "", "require_shipping": false , "taxable": false, "Featured_image": null, "disponible": true, "name": "Modèle de bonnet simple à tricoter", "public_title": null, "options": ["Titre par défaut"], "price ": 450," weight ": 0," compare_at_price ": 450," inventaire_quantity ": 100," Inventory_management ":" shopify "," inventaire_policy ":" continuer "," code-barres ":" ""]]
# 116057
# kget@kde. org
# File extension: .kar
# Extension de fichier: .kar
# 116058
# La Palma
# from Palma
# des de Palma
# 116059
# Pair of Dragons
# Drakòn is a Greek form of drakon, meaning dragon.
# Drakòn est une déformation issue grec drakon, dragon.
# 116060
# Could not set time: %1 / %2 / %3; %4: %5: %6
# Using HtmlAgilityPack - not able yet to come up with a solution!
# Utiliser HtmlAgilityPack - pas encore en mesure de trouver une solution!
# 116061
# kdiff3 test. cpp ftp: / /ftp. faraway. org/ test. cpp kdiff3 tar: / home/ hacker/ archive. tar. gz/ dir. / dir
# In the bot answers, you'll notice the use of 3 special codes :
# Dans les réponses du bot, on remarquera l'utilisation de 3 codes spéciaux :
# 116062
# moderate snow
# light snow
# légères chutes de neige
# 116063
# Specifies whether to use a logarithmic instead of a linear gradient for the Kalzium van der Waals Radius Gradient feature
# What can I do with Godot? How much does it cost? What are the license terms?
# Que puis-je faire avec Godot ? Combien coûte-t-il ? Quels sont les termes de la licence ?
# 116064
# Words with user-defined delimiters are only separated at the end of a line at the point where a user-defined delimiter has been inserted, irrespective of whether the automatic hyphenation is activated or deactivated.
# let’s you write expressions <p>[% like_this %]</p>. The start and end is separated with a space character.
# vous permet d’écrire des expressions <p>[% comme_ca %]</p>. Les caractères de début et de fin sont séparés par un caractère espace.
# 116065
# Amarok has outstanding support for Apple's iPod, iRiver's ifp and a multitude of generic USB devices. It also features many different audio backends allowing YOU to choose how you listen to your music. These and other features make it the most advanced audio player available. & amarok; is smart, sexy and clever. We hope that its use will truly allow you to "Rediscover your music!"
# The Fono MM is a moving magnet disc stage which has been designed to be effective, easy to use and above all reproduce music. The new surface mount board layout has been optimised to work with the latest generation of RP turntables.
# Le Fono MM est un mouvement de disque magnétique qui a été conçu pour être efficace, facile à utiliser et surtout reproduire la musique. La nouvelle plaque de montage en surface a été optimisée pour fonctionner avec la dernière génération de platines RP.
# 116066
# Compare/ Merge Files/ Directories
# Usage of MergeDB
# L’utilisation de MergeDB
# 116067
# Standing order
# Order confirmed
# Commande confirmée
# 116068
# School, university
# School/University
# Ecole/Université
# 116069
# Keep clipboard contents
# Keep current data
# Conserver les données actuelles
# 116070
# Select the shape by its name from the list box.
# Browse our selection by type
# Parcourez notre sélection par type
# 116071
# Hotkey combination
# KEY-WORD "ENERGY"
# MOT-CLE "ENERGIE"
# 116072
# JCL
# About JCC
# A propos de JCC
# 116073
# Boulder Creek
# THE POWER OF STONES
# LE POUVOIR DES PIERRES
# 116074
# /text/simpress/01/03090000.xhp
# Page 1 of 3123NEXT
# Page 1 sur 212NEXT
# 116075
# To specify a replacement style, select a style from the Replace with list.
# Recommended replacement part for:
# Pièce de rechange recommandée pour:
# 116076
# There is also an overview category All, which displays all the file types in one list, without categorizing them.
# Can be used to easily separate different applications/users/groups
# Peut être utilisé pour séparer facilement les applications/utilisateurs/groupes
# 116077
# 漢字 かな romaji
# Adopted texts on Roma
# Textes adoptés sur les Roms
# 116078
# Returns TRUE if the filename exists and is readable.
# Get access to meaningful data. That you can easily interpret and that looks good.
# Accédez à des données pertinentes. Que vous pouvez facilement interpréter, et qui présentent bien.
# 116079
# You can write here various notes associated with the project or/ and a project summary.
# RESEARCH AND REPORT WRITING
# RECHERCHE ET RÉDACTION DE RAPPORTS
# 116080
# The currently selected window will be highlighted by fading out all other windows. This option requires desktop effects to be active.
# How to remove a program from a computer (Windows 10): several basic ways
# Comment supprimer un programme d'un ordinateur (Windows 10): plusieurs façons basiques
# 116081
# Allows you to select a slide design for the presentation you selected on page 1 of the Wizard.
# To get a demo of CAD VCL Enterprise 10.1, please contact us by e-mail or fill in the form.
# Pour obtenir une version de démonstration de CAD VCL Enterprise 10.1, veuillez nous contacter par e-mail ou remplir la forme.
# 116082
# Contributing to & kde;
# & Contribute
# & Contribuer
# 116083
# Ceuta
# Ulibka
# Serges
# 116084
# Approximation. approx(a)=a±n
# Contrast: A A A
# Langue : Contraste : A A ATaille Police : A A A
# 116085
# Very Large (1600x1200)
# Large span lengths and the largest span is over 1000m
# Les longueurs de grande envergure et la plus grande envergure est plus de 1000m
# 116086
# & Translucency
# Transdisciplinary
# Transdisciplinaire
# 116087
# The filename of the user's custom image file
# Name and URL of the file retrieved
# Nom et URL du fichier consulté
# 116088
# Specifies the type of search.
# search Enter your search criteria:
# search Entrez vos critères de recherche:
# 116089
# Export to Several Files
# You can upload multiple files.
# Vous pouvez télécharger plusieurs fichiers.
# 116090
# KSystemlog
# Reference: KfixProBB
# Référence : KfixProBB
# 116091
# Focus window:
# The Vision Group
# Le groupe Vision
# 116092
# Committing...
# amd, committed
# amd, engagée
# 116093
# Translates an DocBook XML file using a PO file
# Send us a doc, docx, pdf, txt, zip file (size less than 1mb):
# Envoyez-nous un fichier doc, docx, pdf, txt, zip (ne doit pas excéder 1 mb) :
# 116094
# \t\t The N, S, E, W keys will point the display at the North, \t\t\tSouth, East and West points on the Horizon. The Z key will point the \t\t\tdisplay at the Zenith. \t\t \t
# Reference: tk-tor80-x
# Référence: tk-tor80-x
# 116095
# Black:
# black ()
# Noir ()
# 116096
# As the last child of the active object
# Last Known Location
# Dernier emplacement connu
# 116097
# Found devices:
# with your device.
# avec votre appareil.
# 116098
# is the date within the calendar week.
# Date (year/month/day)
# Date (jour/mois/année)
# 116099
# A kioslave for ISO9660 filesystems
# ProductsTS6400DN
# ProduitsTS6400DN
# 116100
# ERROR: Invalid WAIT command.
# Error: Invalid procedure call or argument
# Erreur: appel ou argument de procédure non valide
# 116101
# & kpager;
# Model:klkb
# Modèle :klkb
# 116102
# Tellico supports several different data sources.
# You have several platforms available to do that:
# Vous avez plusieurs plateformes disponibles pour le faire:
# 116103
# & Autodetect
# Compare with AutoCAD®
# Comparer avec AutoCAD®.
# 116104
# This action will export all your active events, to-dos and journal entries (independent of to what resource they belong) as a new vCalendar file.
# You need to retransmit a Streaming Event We have all the equipment by Streaming you need [...]
# Vous devez retransmettre un événement de diffusion en continu Nous avons tout l'équipement en Streaming dont [...]
# 116105
# Cannot find any database for temporary connection.
# In this site it is not able to register and therefore do not store nor do we store data.
# Dans ce site, il n'est pas en mesure d'enregistrer et donc ne pas stocker ni ne nous enregistrons des données.
# 116106
# Program new & kde; applications. Please refer to for more information.
# Create a new Feature request
# Créer une nouvelle demande de fonctionnalité
# 116107
# cell protection; unprotecting
# Your Status: Unprotected
# Votre statut: Non-Protégé
# 116108
# Item layout:
# Features and order information
# Caractéristiques et information d'ordre
# 116109
# Finds win and os2win, but not win95 or upwind
# because they were not very important or were not enhanced by
# parce qu'ils n'étaient pas très importants ou n'ont pas été rehaussés par politique
# 116110
# See also ctype_alnum(), ctype_print(), and ctype_punct().
# To cite or learn more about PATRIC, see:
# Pour citer ou en savoir plus sur PATRIC, voir:
# 116111
# OFFICER OF TOMB
# Monument_ Museum_ Antiquarian
# Monument_ Musée_ Antiquaire
# 116112
# Fade effect
# Then disappears ...
# Puis disparaît ...
# 116113
# \\emph{emphasized text}
# Text on the image above:
# Texte de l’image ci-dessous:
# 116114
# Bit depth:
# Depth †
# Profondeur †
# 116115
# honeydew
# A life of honey
# Une vie de miel
# 116116
# The building blocks of a & kommander; dialog are the widgets. They are like any other widget in the & Qt; and & kde; libraries except they have some extra functionality that allows them to have a text association. Text is associated with a state of the widget or its populate slot. The number of states depends on the widget. If a widget only has one state, that state is called default.
# This blog post summarizes the issue we're having. We could use contains, but that only matches the most trivial case for LIKE. Combining contains, startswith, endswith, and indexof gets us there, but requires a translation between standard wildcards and Linq to Entities code.
# Cet article de blog résume le problème rencontré. Nous pourrions utiliser contient, mais cela ne correspond qu'au cas le plus trivial pour LIKE. La combinaison de contient, commence avec, termine avec et index nous amène là, mais nécessite une traduction entre les jokers standard et le code Linq to Entities
# 116117
# Properties...
# Properties
# Les Propriétés
# 116118
# /text/shared/explorer/database/querywizard03.xhp
# O=Options, K=Calendar, N=BBM, M=Messages, $=SMS/MMS, L=Profiles, @=Connections
# O = Options, K = Calendrier, N = BBM, M = $ = Messages, SMS / MMS, L = Profils, @ = Connexions>
# 116119
# Execute specified commands before connect
# Mandatory pre-hiring information session
# Session d'information pré-embauche obligatoire
# 116120
# When there is no rule defined:
# when there is nothing to add,
# non quand il ne reste rien à ajouter,
# 116121
# After entering a date range, open & kedit; or some other text editor and paste the report data.
# - Editing and discussion of the new project of the document can be carried out directly after receipt of remarks.
# - La correction et la discussion du nouveau projet du document peut se réaliser directement après l'entrée des remarques.
# 116122
# SVG Tileset for KDE4
# Maxtoch ZO6X-4 Focusing Cree Led Zoom Flashlight
# Maxtoch ZO6X-4 cris se concentrant Zoom lampe de poche Led
# 116123
# $fruits = array ("d"= "lemon", "a"= "orange", "b"= "banana", "c"= "apple"); ksort ($fruits); reset ($fruits); while (list ($key, $val) = each ($fruits)) {echo "$key = $val\n";}
# Apple and/or pear and mango and mangosteen puree concentrates, apple and/or pear and/or grape and lemon juice concentrates, natural flavour, citrus pectin, apple powder.
# Concentré de purée de pommes et/ou poire, de mangue et de mangoustan, concentrés de jus de pomme et/ou de poire et/ou de raisin et citron, arôme naturel, pectine d'agrumes, poudre de pomme.
# 116124
# Change First Line Indent
# Next post →
# Article suivant →
# 116125
# Edit Recurrence Range
# “The Music” edit
# “La musique” edit
# 116126
# Converts video to black and white
# Click here to see the video on M6 Replay
# Cliquez ici pour voir la vidéo sur M6 Replay
# 116127
# Count flashcard as correct or error
# Handling of error returns (ErrorLevel)
# Gestion des retours d'erreur (ErrorLevel)
# 116128
# Math, can brackets be shown separately so that the distance between them is freely definable?
# (Those generating all the figures of the base, except the complementary figures))
# (Ceux générant tous les chiffres de la base, sauf les chiffres complémentaires)
# 116129
# Configure the toolbars available to & khelpcenter;.
# Shrink-fitting assembly calculation according to E22-621PR: Mechanical transmissions – shrink-fitted assemblies on cylindrical bearing – function, implementation, calculation
# Calcul d’assemblage fretté selon la E22-621PR : Transmissions mécaniques – Assemblages frettés sur portée cylindrique – Fonction, réalisation, calcul
# 116130
# Buyeo
# Buy it
# Achetez-le
# 116131
# _Import format
# _ Request Info _
# _ Demande d’info _
# 116132
# New authtype: "%1".
# 1 - 1 of 1 ads
# 1 - 1 de 1 annonces
# 116133
# Beware that in disconnected IMAP, data are transmitted from a client to IMAP server only when the clients connects to check for new mail. So if you have your & kontact; clients with an interval mail checking of, for instance, 5 minutes, in the worst case you have a 10 minutes delay between the event being written and its appearance to the other users.
# The shipping costs are indicated in the shopping cart before order validation. Delivery within 5 working days for a work without frame and 10 working days for a framed work.
# Les frais de port sont indiqués dans le panier avant validation de la commande. Livraison dans un délai de 5 jours ouvrés pour une oeuvre sans cadre et 10 jours ouvrés pour une oeuvre encadrée.
# 116134
# Edit Copy Input To...
# To edit the riddim (cuts, séquençage…)
# S’il faut éditer le riddim (cuts, séquençage…)
# 116135
# Predefined Constants
# PRE-EXISTING CONDITIONS
# CONDITIONS PRE-EXISTANTES
# 116136
# Login aborted
# Lost your login
# Vous avez perdu votre login
# 116137
# Body:
# FOR THE BODY
# POUR LE CORPS
# 116138
# Some basic information to get encourage people to contribute to & kde;, information about what's available, and how to get started.
# Contact us to discuss suitable recruiting solutions that fit your needs
# Contactez-nous pour discuter de solutions de recrutement adaptées à vos besoins
# 116139
# Use this item to select the whole of the current document.
# (scroll for full list)
# (Faites défiler pour voir la liste complète)
# 116140
# Default reconciliation state for transactions entered during reconciliation of an account
# Reconciliation of accounts with a bank statement.
# Rapprochement des comptes avec un relevé bancaire.
# 116141
# x 1/ y
# Model Number: XY-S01
# Numéro de modèle: XY-S01
# 116142
# New Tag...
# New (1)
# Nouveau (1)
# 116143
# Delete the wallet
# Drop your .jpg or .png files here!
# Déposez vos fichiers .jpg ou .png ici!
# 116144
# Restores the default value for the optimal row height.
# Permanent Makeup
# Maquillage Permanent
# 116145
# Expunging deleted messages
# The page has been deleted, renamed, moved
# Il est possible que cette page ait été supprimée, renommée, déplacée
# 116146
# Privacy Settings
# Privacy POLICY
# POLITIQUE DE CONFIDENTIALITÉ
# 116147
# Select the database type for the existing database connection.
# To download the links in this section, you have to log in to your sedap account or create an account .
# Pour télécharger les liens de cette section, vous devez vous connecter à l’administration sedap avec vos identifiants (ou créer un nouveau compte ).
# 116148
# Use tablet & angle
# Type: Tablet
# Art: Tablette
# 116149
# Afton
# Sidrè
# Sidré
# 116150
# If you do not display these changes in the design view, you cannot change back to the design view.
# Unique features set the standards rather than follow others.
# . Caractéristiques uniques établissent les normes plutôt que de suivre les autres.
# 116151
# Include Birdstep support.
# Support geographically distributed teams
# Supporter des équipes distribuées géographiquement
# 116152
# Template Preview
# The prototype:
# Le prototype:
# 116153
# New icon:
# A New Look
# Un nouveau « look »
# 116154
# Tools Highlight Mode
# Tools to Use
# Outils à utiliser
# 116155
# pages; scaling
# BienvenueMaison de Get Upper
# Bienvenue à Get Upper
# 116156
# Could not save to `%s': %s
# ALL THE PAYMENT ARE NOT REFUNDABLE
# TOUS LES RÉGLEMENTS RÉALISÉS NE SONT PAS REMBOURSABLES.
# 116157
# SEXDEC(1; 5; 7) returns 1.0852778
# XTZ S. TENERE There are 5 products.
# XTZ S. TENERE Il y a 5 produits.
# 116158
# Match also window & title
# and many more that we'll eventually revealing.
# et bien d'autres que nous allons finalement révéler.
# 116159
# bad jump
# This is a bad idea.
# C'est une mauvaise idée
# 116160
# EXIF/ IPTC info to show in the Viewer
# For this subject, please see our info page!
# Lisez plus concernant ce sujet à notre page d'information!
# 116161
# With & cervisia;, you lock files as follows. Select the desired files in the main view. Then choose Advanced Lock Files. This runs the command
# First Click “Office Button”, then “Publish”, Now “Package for CD”. Now there will be a dialog box which you can make some choices:
# Première "Bouton Office" Cliquez, puis "Publier", maintenant "Package pour CD". Maintenant, il y aura une boîte de dialogue que vous pouvez faire des choix:
# 116162
# Superscript top
# ^ Top of the page
# ^ Haut de la page
# 116163
# \[ \]
# A#;Am;C;Dm;F
# C;D;F;G
# 116164
# & Edits
# [ edit this section ]
# [ Modifier cette section ]
# 116165
# Correct the pitch of a voice singing out of tune
# (Note: If you can do this while you talk or sing, you are doing it correctly. If it is necessary to take a deep breath each time, it is being done incorrectly.)
# (Marquez : si vous pouvez faire cela, pendant que vous dites ou chantez, vous faites cela correctement. S&apos;il est nécessaire profondément de soupirer chaque fois, quand cela se fait incorrectement.)
# 116166
# TIMEVALUE function
# Time factor
# Le facteur temps
# 116167
# Open group so that you can edit the individual components (in legend and data series).
# We can now define “local administrators” who can create and delete users within a specific organisation.
# Nous pouvons à présent définir des “administrateurs locaux” qui peuvent créer et supprimer des utilisateurs au sein d’une organisation en particulier.
# 116168
# X authentication
# The card device X
# La carte de l'appareil X
# 116169
# Questions about Dialing
# How do they answer this call?
# Comment répondent-elles à cet appel?
# 116170
# KDE utility for making a fine cup of tea.
# Unique function of Hot water for Tea.
# Fonction unique de l'eau chaude pour le thé.
# 116171
# Save & List...
# < Return to list
# < Retourner à la liste
# 116172
# Enter usage description:
# Enter description
# Entrer la description
# 116173
# IPTC7901 Recommended Message Format
# ASSESSMENT GUIDELINES -
# DIRECTIVES D'ÉVALUATION :
# 116174
# The setting Enable filters enables or disables the use of list of URL filters.
# Search portal. You can limit results by using available filters.
# Recherche sur la totalité du contenu du portail. Vous pouvez limiter les résultats en utilisant les filtres disponibles.
# 116175
# Display field
# Field: Image
# Domaine : Image
# 116176
# /text/smath/01/03090100.xhp
# Adobe Reader X Exercise, Level I
# Exercice avec Adobe Reader X, niveau I
# 116177
# Alternative Enclosures:
# Additional Information on Alternative Accommodation:
# Information supplémentaire sur des alternatives d'hébergement:
# 116178
# testtube. svg
# DISCOVER CADILLAC
# DÉCOUVRIR CADILLAC
# 116179
# Protection can be provided by means of a password, but it does not have to be.
# This does not mean that we guarantee your password has not been leaked, but we cannot find any public record of it.
# Cela ne signifie pas que nous garantissons que votre mot de passe n'a pas été divulgué, mais nous ne pouvons trouver aucun enregistrement public.
# 116180
# Font & & Color
# Text color
# Couleur du texte
# 116181
# Analyse MIDI messages through JACK
# Groups of keys on models SpaceExplorer (at the left) and SpacePilot (on the right)
# Les groupes des touches sur les modèles SpaceExplorer (à gauche) et SpacePilot (à droite)
# 116182
# ) button next to the box.
# by fax : 418-888-5029
# par télécopieur : 418-888-5029
# 116183
# If you try to assign a shortcut that is already used, it will give you a warning message. Highlight what you want to do (in the picture, I have chosen to make a keyboard shortcut to About KDE).
# If you are wondering how to block a number on your Moto X, read this post and learn the detailed steps to achieve it.
# Si vous vous demandez comment bloquer un numéro sur votre Moto X, lisez ce post et apprenez les étapes détaillées pour y parvenir.
# 116184
# Todor Gyumyushev
# by Sergey Klimkin
# by Sergueï Klimkine
# 116185
# Display each virtual desktop on the side of a sphere
# Discover it on desktop or tablet.
# Découvrez là sur desktop et tablette.
# 116186
# Advanced Unedit Files
# (Uncategorised Content)
# (Non catégorisé contenu)
# 116187
# There are three possible positions for new objects:
# new programmes, spaces or third places
# de nouveaux programmes, espaces ou tiers-lieux
# 116188
# Not Norway
# And you're not a bird.
# Et tu n'es pas un oiseau.
# 116189
# Ports
# of the port
# de port
# 116190
# If no type-declaration character or keyword is specified, the DefBool statement sets the default data type for variables, according to a letter range.
# Note: When you want to refer to a specific question, always put the name between {} and preceded by a $.
# Remarque : Quand vous voulez faire référence à une question specifique, mettez toujours le nom entre {} et précédé par un $ .
# 116191
# BITXOR(12; 10) returns 6 (because decimal 12 is binary 1100, and decimal 10 is binary 1010; and 1100 "xored" with 1010 is 0110, which is integer 6).
# Product Size 960*400*110mm 1260*400*110mm
# Dimension de produit 960*400*110mm 1260*400*110mm
# 116192
# Roll Dice
# Stock: M2276
# INVENTAIRE: M2276
# 116193
# Format Align Objects
# Indicate or Mark recognition on components.
# Indiquer ou reconnaissance de marques sur les composants.
# 116194
# Montauban
# montpellier
# Montpellier, France
# 116195
# No write
# No project
# Aucun projet
# 116196
# Visit contributor's Twitter feed
# ACCESS TWITTER HERE
# ACCÈS Twitter ici
# 116197
# Manual Text
# Information and manual
# Informations et manuel
# 116198
# When " standard deviation " is selected, y is the mean value of the data series.
# Rapport quality / price:
# Rapport qualité / prix:
# 116199
# < ? > le < ? >
# ?&gt;
# Mise à Jour
# 116200
# Import OPML File
# Importing data
# Importer des données
# 116201
# KDevQuantaCore
# Trellis
# Treillis
# 116202
# Al-Ubayyid
# Ubaxis Agency
# Agence Ubaxis
# 116203
# In fact, & kpovmodeler; offers you a convenient feature: You can create a infinite plane that will feature the ground:
# Landing Page Design That Converts Well
# Page d'atterrissage de conception qui convertit bien
# 116204
# Full%
# version Full version
# version Pleine version
# 116205
# to:
# AND:
# ET :
# 116206
# Yes; to start kstars with the clock paused, simply add the --paused argument to the command line.
# Be the first to review “SUPER73 Z” Cancel reply
# Soyez le premier à laisser votre avis sur “SUPER73 Z” Annuler la réponse
# 116207
# Mail Component
# MAILING LIST
# LISTE DE DIFFUSION
# 116208
# If this option is checked, & kde; will show a confirmation dialog whenever a keyboard accessibility feature is turned on or off.
# How to display a confirmation dialog when clicking an <a> link?
# Comment afficher une boîte de dialogue de confirmation en cliquant sur un lien <a>?
# 116209
# number completion on/off
# Data: Date of completion.
# Données: Date d'achèvement.
# 116210
# You can insert sections into an existing section.
# These constructions can now act as the location in a sentence:
# Ces constructions peuvent maintenant agir comme location dans une phrase :
# 116211
# Manual upload approval
# Automate the localization process from start to finish
# Automatiser le processus de localisation du début à la fin
# 116212
# C/C++/Java/Vala
# C, C++, Java: Intermediate
# C++ et Java: intermédiaire
# 116213
# barrel game
# What is the video option?
# Quelle est l'option vidéo?
# 116214
# ...
# Couverture nuageuse : 1 %
# 117055
# Sotho, Southern
# OEM South
# OEM Sur
# 117056
# Click in a cell in the larger table that contains a number, press the plus sign (+), and then click in a different cell containing a number.
# Each of the quizzes below include 15 multiple-choice style questions on the nervous system.
# Chacun des quiz ci-dessous comprend 15 questions à choix multiples sur le système nerveux.
# 117057
# /text/scalc/01/05040000.xhp
# Reference: CD0490-104
# Référence: CD0490-104
# 117058
# By default this check box is not marked, so you will not get any e-mail.
# It is not possible to remove or peel off the Trustseal from the box because it is not a sticker.
# Il n'est pas possible d'enlever ou de décoller le Trustseal de la boîte car ce n'est pas un autocollant.
# 117059
# If you are on the last step, this button becomes
# Last part of the interview coming soon!
# Dernière partie de l’interview bientôt disponible !
# 117060
# Defines the interval for the subdivision of the axes.
# 1.Product Model Number: RXCH0907-1
# 1. Numéro de modèle du produit: RXCH0907-1
# 117061
# & Build new index
# 1) Create a new file.
# 1) Créer un nouveau fichier.
# 117062
# Start at line:
# * Directly go to a specified line number
# * Aller directement à un numéro de ligne spécifié
# 117063
# Persistent connections were designed to have one-to-one mapping to regular connections.
# tal beings. I was told to make this information accessible
# êtres de tal. On m'a dit de rendre cette information accessible
# 117064
# hocr-gtk
# hr _
# Ensemble
# 117065
# A tool to export pictures to or import from a remote directory that is accessible via KIO.
# For us to be able to help you, download our remote control software
# Pour que nous puissions vous aider, téléchargez notre logiciel de prise en main à distance
# 117066
# Loading Projects
# Loading phase
# Phase de chargement
# 117067
# INT(x)
# Model No.:xz-0017
# Modèle:xz-0017
# 117068
# Lambert
# Lambert Award
# Prix Lambert
# 117069
# Flag manager
# Managing Director's Message
# Message du Directeur
# 117070
# false if type has an invalid value, or if no template with the name templateName can be found; true otherwise.
# Identification of data quality issues: null, incorrect, inconsistent, illegible, etc.
# Identification des problèmes liés à la qualité des données : valeurs nulles, incorrectes, incohérentes, illisibles, etc...
# 117071
# Path to certificates directory for IPSec
# 4. You will see API URL and Authentication Token
# 4. Vous verrez "API URL" et "Authentication Token"
# 117072
# Mark'It's good, but it's not irssi 'Kretschmann
# Hypoallergenic, Not Irritant,
# Hypoallergénique, Non irritant,
# 117073
# ... that you can insert any number of lines using the Multiline element? By inserting you can align these lines.
# Now, you can create multi-line text, align it left/right or make it center and set the amount of space between words.
# Désormais, vous pouvez créer un texte multiligne, l’aligner sur la gauche, la droite, ou le centrer et fixer la quantité d’espace entre les mots.
# 117074
# To change the value of the variable later in the document, insert another Input field of the same name, but with a different value.
# how to change the type of the parameter in an Expression?
# Comment changer le type du paramètre dans une expression?
# 117075
# Gas particle
# Gas Phase
# Phase de gaz
# 117076
# Vietnamese Male
# Language: Vietnamese
# Langue : Vietnamien
# 117077
# My Searches
# My search...:
# Ma recherche... :
# 117078
# Magnolia
# The series "Caprica"
# La série "Caprica"
# 117079
# Preserve times (-t, --times). The modification times are transferred along with the files. For what happens if this option is switched off, please read rsync's manual page.
# You may stop the analysis process by clicking “Stop Analyse”. To run analysis of the selected disk again click the right button on the folder “$ Content-Aware Analysis” and select “Analyse again”.
# Vous pouvez interrompre l’analyse en cliquant sur le bouton « Arrêter l’analyse ». Pour lancer une nouvelle analyse du disque sélectionné, cliquez-droit sur le dossier « $ Analyse détaillée » et sélectionnez « Analyser à nouveau ».
# 117080
# Search terms:
# Search Terms:
# Termes de recherche:
# 117081
# Select the item that you want to add a caption to.
# Select the category you wish to receive information about.
# Sélectionnez la catégorie sur laquelle vous souhaitez recevoir des informations.
# 117082
# resLISa
# Trellis
# Treillis
# 117083
# Tools Convert Tag & Attribute Case...
# Insert search parameters
# Insérer des paramètres de recherche
# 117084
# 22 Inch Roll Paper
# 22mm Diameter
# Diamètre de 22mm
# 117085
# 3x3x3, 6 U
# (3)Length:3-6M
# (3) Longueur : 3-6M
# 117086
# Store the attachment file inside the calendar
# For information and online purchases click here to read the complete programs:
# Cliquez ici pour lire l'intégralité de programmes:
# 117087
# SystemPath
# System information
# Information système
# 117088
# of Gen
# To get to Gennes :
# Pour se rendre à Gennes :
# 117089
# do_while
# Contact _
# Nous joindre _
# 117090
# Color management settings
# Color Management
# Gestion des Couleurs
# 117091
# Drag the bottom left mark to the right while pressing the mouse button
# press the left mouse button
# appuyez sur le bouton gauche de la souris
# 117092
# You assign a name to every scenario on your sheet.
# Complete the form below to be notified of the next scheduled dates.
# Pour être informé des prochaines dates, n'hésitez pas à compléter le formulaire ci-dessous.
# 117093
# , and then apply the styles to the pages where you want the headers or footer to appear.
# Now, you can create multi-line text, align it left/right or make it center and set the amount of space between words.
# Désormais, vous pouvez créer un texte multiligne, l’aligner sur la gauche, la droite, ou le centrer et fixer la quantité d’espace entre les mots.
# 117094
# Enter the text to be displayed at the right side of the header or footer.
# Enter the text shown in the picture on the right
# Veuillez saisir ici le texte qui doit être vu sur l’image de droite:
# 117095
# If the string was not found, the function returns 0.
# returning 0 if successful.
# retournant 0 en cas de réussite.
# 117096
# tables;deleting page breaks before
# If you do not have an account, your files can be deleted at any time by the administrator
# Si vous n'avez pas de compte, vos fichiers peuvent être supprimés à tout moment par l'administrateur
# 117097
# Among other things, this can be used to implement callbacks, function tables, and so forth.
# Content scraping can be used for many things. Let’s review some uses cases together.
# Le scraping de contenu peut être utilisé pour beaucoup de choses. Examinons ensemble quelques cas d’utilisation.
# 117098
# Defining Line Ends
# } // end union
# } // fin d'union
# 117099
# set-word-wrap BOOLEAN enable
# Package Include:
# Le paquet incluent:
# 117100
# After a resource was downloaded, but before it is installed, & quantaplus; verifies if the resource is valid, by checking the integrity and the signature. In case of problems it warns you and you can decide if you want to continue or not. Please read the warning dialogs carefully. In the case when the integrity is correct and the resource is correctly signed, you will still get an information dialog, so you can see who created the resource.
# You can also submit an up-to-date copy of your CV as a speculative application, which will be kept in confidence and form part of our database or until you request its removal.
# Vous pouvez également soumettre une candidature spontanée en nous envoyant une copie de votre CV que nous garderons de manière confidentielle dans notre base de données ou jusqu’à ce que vous nous demandiez de l’effacer.
# 117101
# If this option is selected the lines in the article list are scrolled smoothly instead of jerkily.
# If there are errors, it is easier to browse and analyze
# S'il y a une erreur, il est plus facile de parcourir et d'analyser
# 117102
# Choose the text color for error in typing line
# If you notice an error in the text, select it and press Ctrl + Enter to send the information to the editor.
# Si vous remarquez une erreur dans le texte, sélectionnez-le et appuyez sur Ctrl + Entrée pour envoyer les informations à l'éditeur.
# 117103
# A hatches list file has the format [filename].soh.
# - Sorbothane with plugin (Details)
# - Sorbothane avec plugin (Détails)
# 117104
# Preload an instance after KDE startup
# Training at Sedron Technologies of Delvic technical team in charge of the Omniprocessor Thursday July 4th, 2019
# Formation à Sedron Technologies de l’équipe technique de Delvic en charge de l’Omniprocessor jeudi 4 juillet 2019
# 117105
# Manual Rules
# Basic regulations of use:
# Normes élémentaires d’utilisation :
# 117106
# Disable & tree view
# Remove This Item Category: Forest, Josée
# Supprimer le filtre Catégorie: Forest, Josée
# 117107
# If so, go to the src / modules / php4 directory inside your apache source directory and run this command: ranlib libmodphp4.a Then go back to the root of the apache source directory and run the above configure command again.
# Run your cgi scripts. SSI, Perl.
# Exécutez vos scripts cgi. SSI, Perl.
# 117108
# Unable to construct a GUI element. Your KMLDonkey installation is incomplete.
# In this site it is not able to register and therefore do not store nor do we store data.
# Dans ce site, il n'est pas en mesure d'enregistrer et donc ne pas stocker ni ne nous enregistrons des données.
# 117109
# Searches the folder for duplicate messages and deletes the duplicates.
# NODouble - Search for duplicate files - Find and delete duplicates
# NODouble - Rechercher les fichiers en double - Trouver et supprimer les doublons (fichiers dupliqués)
# 117110
# The Result tab displays the Date, Account, Details, Reconciliation status, Payment, and Deposit for each transaction that matches the search criteria you have entered. Right clicking on the header row of the results list allows you to alter the sort order of the results.
# Export an xml sitemap for submission to the search engines (and in other formats too - including .dot for making visualisations). Option to include images and pdf files. Set up rules for your priority / change frequency or edit these manually.
# Exportez un fichier sitemap xml pour le soumettre aux moteurs de recherche (et dans d'autres formats aussi - y compris en .dot pour pouvoir le visualiser). Possibilité d'inclure des images et des fichiers pdf. Configurez les règles de priorité / la fréquence de changement ou modifiez-les manuellement.
# 117111
# Could not open '%s' in '%s'
# Could not go up step.
# Ne peut pas monter une marche.
# 117112
# Show on Bottom Left
# At the left of the timeline:
# A gauche de la timeline:
# 117113
# modified on %1
# Rectifying 1 unit
# Rectification 1 unité
# 117114
# Restricted application: %s
# Restricted Application:
# application restreinte:
# 117115
# A session has exited with non-zero status
# Closed issues (0)
# Problèmes clôturés (0)
# 117116
# p, li {white-space: pre-wrap;} The amount of data at the beginning and end of a video file, which will be prioritized for previewing.
# Let's start! If you'd like to follow along to a video, we've included one below:
# Commençons! Si vous souhaitez suivre une vidéo, nous en avons inclus une ci-dessous:
# 117117
# Private & Key:
# Client: private
# Maître d'Ouvrage: privé
# 117118
# File Save as Draft
# Just submit your file and you will receive a compressed version within a short moment.
# Envoyez simplement votre fichier et vous recevrez une version compressée dans un bref instant.
# 117119
# Project level
# Project mode
# Mode projet
# 117120
# The Options tab form allows configuration of the options supported by the diff program.
# You can filter the results obtained by geographical location, domain, platform, duration, etc.
# Vous pouvez filtrer les résultats obtenus par lieu géographique, domaine, plateforme, durée, etc.
# 117121
# Playlist Clear
# It's all within your reach.
# Tout est à votre portée.
# 117122
# Janesville
# By Jean
# Par Jean
# 117123
# Font for Messages
# Text for the data line.
# Texte pour la ligne de données.
# 117124
# The ASCII values to convert
# Illustration of front and back cover: Winshluss
# Illustrations de première et quatrième de couverture : Winshluss
# 117125
# V.42bis
# Fw 42 mm
# D 72 mm
# 117126
# See also: mysql_get_host_info(), mysql_get_proto_info() and mysql_get_server_info().
# Web Hosting - Domain Name - Protection - Servers - Programming and Web Development - Design - Technical Support
# Hébergement Web - Nom de domaine - Protection - Serveurs - Programmation et développement Web - Design - Support technique
# 117127
# Reviews
# Reviews
# INFORMATIONS
# 117128
# toolbars;curves
# The machine can do curve category:
# La machine peut faire la catégorie de courbe:
# 117129
# New Zoom level
# More From Zoom
# En savoir plus sur Zoom
# 117130
# & Profiles:
# Profiles
# Billets
# 117131
# Choose an icon.
# Choose an icon
# Choix de l'icone
# 117132
# To enter multiple values, press Shift + Enter after each input line.
# Rearrange the pages by dragging them with your finger .
# Réorganiser les pages, en les faisant glisser avec le doigt .
# 117133
# Security detail wizard
# Magic Guard
# Garde Magik
# 117134
# Tonemapping...
# also known as MAGDA
# aussi connu/e comme MAGDA
# 117135
# While you type you may make mistakes and hit the wrong key. In that case the student's line will change its color (per default to red) and you have to hit Backspace to erase the wrong character (or characters) again.
# Let's go, let that, the tutorial you saw, or you're just a terrorist of words looking for mistakes that help round the ego.
# Allons-y, laissez cela, le tutoriel que vous avez vu, ou vous êtes juste un terroriste de mots à la recherche d'erreurs qui aident à contourner l'ego.
# 117136
# False bricks, otherwise known as fall-through bricks or traps, are the other hidden feature of the game. They look just like ordinary bricks, but if you run over one you fall. This can be bad if there is an enemy or a pit down there, or good if there is some gold.
# Do you like games like Quake? Then this game is just for you!
# Vous aimez les jeux comme Quake? Alors ce jeu est fait pour vous!
# 117137
# Append fetch data
# How to obtain it :
# Comment l'obtenir :
# 117138
# Attention: if the & CD; could successfully fetched from freedb, all song titles will already be filled out and above the track list, the artist and album name will be shown.
# We can offer all kinds of fiber optic adapters,100% test before delivery:
# Nous pouvons offrir toutes sortes d'adaptateurs optiques de fibre, essai de 100% avant la livraison :
# 117139
# overwrite dialog in Calc if target is not empty
# Console feedback Time, distance, speed, calories, program, level, pulse, watts, tower, heart rate, rounds
# Affichage console Temps, distance, vitesse, calories, programme, niveaux, wattage, poul, tours
# 117140
# Other & printer type
# Printing options
# Options d'impression
# 117141
# You can save the document and open it on another computer, and the inserted object will still be in the same position in the document.
# - The free re-activation of software in case of change or format the computer
# - La réactivation gratuite du logiciel dans le cas d'un changement ou d'un formatage d'ordinateur
# 117142
# Geolocation from gps address
# Geolocation: GPS
# Géolocalisation : GPS
# 117143
# The reason for the two different variations of "and" and "or "operators is that they operate at different precedences. (See Operator Precedence.)
# There are multiple qualities necessary. Simply put, I would be tempted to say that it is important to know the difference between quality and … the contrary.
# Les qualités requises sont multiples. Pour faire simple, je serais tentée de dire qu’il faut savoir preuve d’une qualité …et de son contraire.
# 117144
# Nth term
# h/Year
# h/Année
# 117145
# sText = " RGB= " & Red(QBColor( iColour) ) & " : " & Blue(QBColor( iColour) ) & " : " & Green(QBColor( iColour) )
# Red, Green, Blue, White, RGB, RGBW
# Rouge, Vert, Blue, Blanc, RGBW
# 117146
# & korganizer; can be easily controlled with your mouse. The supported drag-and-drop operations are detailed below.
# The prescription is simple: digitization, multi-channel integration, and bots.
# La prescription est simple : numérisation, intégration multi-canal et chatbots.
# 117147
# Select the text from the list box.
# Add to Cart: Please Choose: Type
# Ajouter au Panier : Veuillez Sélectionner :
